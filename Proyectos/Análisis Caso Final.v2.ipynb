# %% [markdown]
# # 📊 Caso de análisis: Emisiones de dióxido de carbono por país (1975-2017)
# ## 🧠 Objetivo:
# Los estudiantes deben analizar la evolución de las emisiones de CO₂ en varios países desde 1975 hasta 2017, distinguiendo entre:
#
# - Emisiones totales: Miden la cantidad total de CO₂ emitido en un país.
#
# - Emisiones per cápita: Indican cuántas toneladas métricas de CO₂ emite, en promedio, una persona en ese país.

# %% [markdown]
# ## <mark>Estudiante: \> Stephanny Garita Vega</mark>

# %% [markdown]
# ## Contexto

# %% [markdown]
# 🌍 Análisis de Emisiones de CO₂ – Caso Práctico
# 📁 Archivo: Carbon_Dioxide_Emission_Estimates.csv
# Contiene datos de emisiones de dióxido de carbono (CO₂) de varios países entre 1975 y 2017.
#
# 🧾 Estructura de los datos
# - Country: País
#
# - Year: Año
#
# - Type: Tipo de emisión:
#
#     * Emisiones totales (kilotoneladas métricas)
#
#     * Emisiones per cápita (toneladas métricas por persona)
#
# - Value: Valor numérico de la emisión
#
# 🔍 Tipos de emisiones
# - Totales: CO₂ emitido por todo el país (kt)
#
# - Per cápita: CO₂ promedio por persona (t CO₂/persona)
#
#     - Se calcula dividiendo emisiones totales por la población

# %%
#Importa el CSV como un DataFrame

import pandas as pd
import os
import matplotlib.pyplot as plt

df=pd.read_csv('Estimaciones_Emisiones_Dioxido_Carbono.csv')

# %% [markdown]
# # Pregunta 0
#
# 1. Crear un dataframe con el nombre de variable 'df_emisions_co2' usando únicamente las filas cuya columna 'Type' tiene el valor 'Emisiones totales de CO₂ emitidas por el país'
#
# 2. Crear un dataframe con el nombre de variable 'df_emisions_co2_per_capita' usando únicamente las filas cuya columna 'Type' tiene el valor 'Emisiones promedio de CO₂ emitidas por habitante'.

# %%
#Crea un copia del original filtrado como df_emisions_co2
df_emisions_co2 = df[df["Type"] == 'Emisiones (kilotoneladas metricas de dioxido de carbono)']

# %%
#Crea un copia del original filtrado como df_emisions_co2_per_capita
df_emisions_co2_per_capita = df[df["Type"] == 'Emisiones per capita (toneladas metricas de dioxido de carbono)']

# %% [markdown]
# # Pregunta 1

# %% [markdown]
# Cuántas filas tiene el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui
cantidad_filas=df_emisions_co2.shape[0]
print("La cantidad de filas que tiene el DataFrame df_emisions_co2 es:", cantidad_filas)
# Out:
# La cantidad de filas que tiene el DataFrame df_emisions_co2 es: 1066

# %% [markdown]
# # Pregunta 2

# %% [markdown]
# Cuál es el valor más alto de emisiones (en general) usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
valor_maximo=df_emisions_co2['Value'].max()
print("El valor más alto de emisiones es:", valor_maximo)
# Out:
# El valor más alto de emisiones es: 9257933.9

# %% [markdown]
# # Pregunta 3

# %% [markdown]
# Cuántos países (Countries) hay en el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
df_emisions_co2['Country'].nunique()
# Out:
# 142

# %%
#Imprima un lista con todos los paises
paises = df_emisions_co2['Country'].unique()
print("Lista de países:")
for pais in paises:
    print(pais)
# Out:
# Lista de países:
# Albania
# Algeria
# Angola
# Argentina
# Armenia
# Australia
# Austria
# Azerbaijan
# Bahrain
# Bangladesh
# Belarus
# Belgium
# Benin
# Bolivia (Plurin. State of)
# Bosnia and Herzegovina
# Botswana
# Brazil
# Brunei Darussalam
# Bulgaria
# Cambodia
# Cameroon
# Canada
# Chile
# China
# China Hong Kong SAR
# Colombia
# Congo
# Costa Rica
# Côte d’Ivoire
# Croatia
# Cuba
# Curaçao
# Cyprus
# Czechia
# Dem. People's Rep. Korea
# Dem. Rep. of the Congo
# Denmark
# Dominican Republic
# Ecuador
# Egypt
# El Salvador
# Eritrea
# Estonia
# Ethiopia
# Finland
# France
# Gabon
# Georgia
# Germany
# Ghana
# Gibraltar
# Greece
# Guatemala
# Haiti
# Honduras
# Hungary
# Iceland
# India
# Indonesia
# Iran (Islamic Republic of)
# Iraq
# Ireland
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Kenya
# Kosovo
# Kuwait
# Kyrgyzstan
# Latvia
# Lebanon
# Libya
# Lithuania
# Luxembourg
# Malaysia
# Malta
# Mauritius
# Mexico
# Mongolia
# Montenegro
# Morocco
# Mozambique
# Myanmar
# Namibia
# Nepal
# Netherlands
# New Zealand
# Nicaragua
# Niger
# Nigeria
# Norway
# Oman
# Pakistan
# Panama
# Paraguay
# Peru
# Philippines
# Poland
# Portugal
# Qatar
# Republic of Korea
# Republic of Moldova
# Romania
# Russian Federation
# Saudi Arabia
# Senegal
# Serbia
# Singapore
# Slovakia
# Slovenia
# South Africa
# South Sudan
# Spain
# Sri Lanka
# Sudan
# Suriname
# Sweden
# Switzerland
# Syrian Arab Republic
# Tajikistan
# Thailand
# North Macedonia
# Togo
# Trinidad and Tobago
# Tunisia
# Turkey
# Turkmenistan
# Ukraine
# United Arab Emirates
# United Kingdom
# United Rep. of Tanzania
# United States of America
# Uruguay
# Uzbekistan
# Venezuela (Boliv. Rep. of)
# Viet Nam
# Yemen
# Zambia
# Zimbabwe

# %% [markdown]
# # Pregunta 4

# %% [markdown]
# Cuál es el país que tiene mayor emisiones usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
df_emisions_co2.loc[df_emisions_co2['Value'].idxmax()]
# Out:
# Country                                                China
# Year                                                    2017
# Type       Emisiones (kilotoneladas metricas de dioxido d...
# Value                                              9257933.9
# Name: 353, dtype: object

# %% [markdown]
# # Pregunta 5

# %% [markdown]
# Cuál es el año que tiene mayor emisiones para el país de Spain usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
df_Spain = df_emisions_co2[df_emisions_co2['Country'] == 'Spain']

anio_mayor_emision_spain = df_Spain.loc[df_Spain['Value'].idxmax()]['Year']
print("El año que tiene mayor emisiones para el país de Spain es:", anio_mayor_emision_spain)
# Out:
# El año que tiene mayor emisiones para el país de Spain es: 2005

# %% [markdown]
# # Pregunta 6

# %% [markdown]
# Cuáles son los años que se tiene registros para el dataframe 'df_emisions_co2_per_capita'?
#
# Entrege una lista con los años sin repetirse

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
anios = df_emisions_co2_per_capita['Year'].unique()
print("Años en el DataFrame df_emisions_co2_per_capita:", anios)
# Out:
# Años en el DataFrame df_emisions_co2_per_capita: [1975 1985 1995 2005 2010 2015 2016 2017]

# %% [markdown]
# # Pregunta 7

# %% [markdown]
# Cuántas son las emisiones en 'kilotoneladas métricas' en total usando todos los países para usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
total_emisiones = df_emisions_co2['Value'].sum()
print("El total de emisiones en kilotoneladas métricas de dióxido de carbono es:", total_emisiones)
# Out:
# El total de emisiones en kilotoneladas métricas de dióxido de carbono es: 195028250.41599998

# %% [markdown]
# # Pregunta 8

# %% [markdown]
# Cuántas son las emisiones en 'kilotoneladas métricas' sólo para Albania usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
emisiones_Albania = df_emisions_co2[df_emisions_co2['Country'] == 'Albania']['Value'].sum()
print("El total de emisiones para el país deAlbania es:", emisiones_Albania)
# Out:
# El total de emisiones para el país deAlbania es: 32713.283000000003

# %% [markdown]
# # Pregunta 9

# %% [markdown]
# Cuántas son las emisiones totales en 'libras' sólo para Costa Rica usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
emisiones_costa_rica = df_emisions_co2[df_emisions_co2['Country'] == 'Costa Rica']['Value'].sum()

total_toneladas = emisiones_costa_rica * 1000

total_kilogramos = total_toneladas * 1000

total_libras = total_kilogramos * 2.20462

print("El total de emisiones para el país de Costa Rica en libras es:", total_libras)
# Out:
# El total de emisiones para el país de Costa Rica en libras es: 93085906154.34

# %% [markdown]
# # Pregunta 10

# %% [markdown]
# Para sólo 'Costa Rica' y suponiendo que las emisiones se estancan a partir del último año reportado (se mantiene igual). Cuántas son las emisiones en 'Kg' sólo para Costa Rica desde el ultimo año registrado hasta el 2025 usando el dataframe 'df_emisions_co2'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta

ultimo_anio_costa_rica = df_emisions_co2[df_emisions_co2['Country'] == 'Costa Rica']['Year'].max()
df_emisions_co2[(df_emisions_co2['Country'] == 'Costa Rica') & (df_emisions_co2['Year'] == ultimo_anio_costa_rica)]

emisiones_costa_rica_kilotoneladas = df_emisions_co2[(df_emisions_co2['Country'] == 'Costa Rica') & (df_emisions_co2['Year'] == ultimo_anio_costa_rica)]['Value'].iloc[0]

anio_final = 2025
cantidad_anios = anio_final - ultimo_anio_costa_rica + 1

total_emisiones_costa_rica_kilotoneladas = emisiones_costa_rica_kilotoneladas * cantidad_anios

emisiones_costa_rica_toneladas = emisiones_costa_rica_kilotoneladas * 1000
emisiones_costa_rica_kilogramos = emisiones_costa_rica_toneladas * 1000

print("La cantidad de emisiones para Costa Rica en kilogramos desde el último año registrado hasta el 2025 es: ", emisiones_costa_rica_kilogramos)
# Out:
# La cantidad de emisiones para Costa Rica en kilogramos desde el último año registrado hasta el 2025 es:  7584411000.0

# %% [markdown]
# # Pregunta 12

# %% [markdown]
# Para sólo los países de Centroamérica ['El Salvador', 'Honduras', 'Guatemala', 'Costa Rica', 'Nicaragua'] obtener un reporte por año de las emisiones totales en Centroamérica usando el dataframe 'df_emisions_co2'?
# Se espera un dataframe de 2 columnas: 'Year' y 'total_por_año'

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
paises_centroamerica = ['El Salvador', 'Honduras', 'Guatemala', 'Costa Rica', 'Nicaragua']

df_centroamerica = df_emisions_co2[df_emisions_co2['Country'].isin(paises_centroamerica)]

reporte_centroamerica = df_centroamerica.groupby('Year')['Value'].sum().reset_index()

reporte_centroamerica.columns = ['Year', 'total_por_año']

reporte_centroamerica
# Out:
#    Year  total_por_año
# 0  1975       9860.972
# 1  1985      10250.333
# 2  1995      20960.234
# 3  2005      33562.291
# 4  2010      34533.555
# 5  2015      43107.376
# 6  2016      44366.072
# 7  2017      43556.261

# %% [markdown]
# # Pregunta 13

# %% [markdown]
# Para sólo los países de Centroamérica ['El Salvador', 'Honduras', 'Guatemala', 'Costa Rica', 'Nicaragua'] obtener un reporte por año de las emisiones en promedio en Centroamérica usando el dataframe 'df_emisions_co2_per_capita'?
# Se espera un dataframe de 2 columnas: 'Year' y 'promedio_por_año'

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
paises_centroamerica = ['El Salvador', 'Honduras', 'Guatemala', 'Costa Rica', 'Nicaragua']

df_centroamerica = df_emisions_co2_per_capita[df_emisions_co2_per_capita['Country'].isin(paises_centroamerica)]

df_promedio_por_anio = df_centroamerica.groupby('Year')['Value'].mean().reset_index()

df_promedio_por_anio.rename(columns={'Value': 'promedio_por_año'}, inplace=True)

df_promedio_por_anio
# Out:
#    Year  promedio_por_año
# 0  1975            0.5690
# 1  1985            0.4620
# 2  1995            0.7626
# 3  2005            0.9720
# 4  2010            0.9538
# 5  2015            1.0572
# 6  2016            1.0720
# 7  2017            1.0422

# %% [markdown]
# # Pregunta 14

# %% [markdown]
# Cuál es el promedio de las emisiones per capita para el año 2005 usando el dataframe 'df_emisions_co2_per_capita'?

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta
promedio_2005 = df_emisions_co2_per_capita[df_emisions_co2_per_capita['Year'] == 2005]['Value'].mean()
print(f"El promedio de emisiones per cápita en 2005 es: {promedio_2005}")
# Out:
# El promedio de emisiones per cápita en 2005 es: 5.29775

# %% [markdown]
# # Pregunta 15
#
# Usa el dataframe  'df_emisions_co2_per_capita' con las columnas Year y promedio_por_año para crear una gráfica de líneas que muestre la evolución del promedio de emisiones per cápita en Centroamérica a lo largo del tiempo; el eje X debe ser el año y el eje Y el promedio de emisiones.

# %%
# Coloque el código que responda a la pregunta aqui exactamente lo que se pregunta

plt.plot(df_promedio_por_anio['Year'], df_promedio_por_anio['promedio_por_año'])
plt.xlabel("Año")
plt.ylabel("Promedio de emisiones per cápita")
plt.title("Evolución del promedio de emisiones per cápita en Centroamérica")
plt.grid(True)
plt.show()

# %% [markdown]
# **"La programación no es sobre lo que sabes, sino sobre lo que eres capaz de aprender."**
# – *Chris DiBona*
